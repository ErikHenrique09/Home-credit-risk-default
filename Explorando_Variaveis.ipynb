# %% [markdown]
# <center><h1>Explorando variaveis</h1></center>
#
#
# O problema disponibiliza um  arquivo de dicionario das variaveis das bases de dados, este arquivo auxiliou nas analises e entendimento do problema

# %%
from uteis.modules import *

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
hccd = pd.read_csv("../datasets/HomeCredit_columns_description.csv",
                   encoding_errors='ignore',
                   index_col = False
                  )

# %%
hccd.drop('Unnamed: 0', axis=1, inplace=True)

# %%
hccd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Table        219 non-null    object
#  1   Row          219 non-null    object
#  2   Description  219 non-null    object
#  3   Special      86 non-null     object
# dtypes: object(4)
# memory usage: 7.0+ KB

# %% [markdown]
# ### Descrições sobre as features do arquivo application_{train|test}.csv

# %%
app_train_test = hccd[hccd.Table == 'application_{train|test}.csv'].drop(['Table','Special'], axis = 1)

# %%
app_train_test
# Out:
#                               Row  \
# 0                      SK_ID_CURR
# 1                          TARGET
# 2              NAME_CONTRACT_TYPE
# 3                     CODE_GENDER
# 4                    FLAG_OWN_CAR
# 5                 FLAG_OWN_REALTY
# 6                    CNT_CHILDREN
# 7                AMT_INCOME_TOTAL
# 8                      AMT_CREDIT
# 9                     AMT_ANNUITY
# 10                AMT_GOODS_PRICE
# 11                NAME_TYPE_SUITE
# 12               NAME_INCOME_TYPE
# 13            NAME_EDUCATION_TYPE
# 14             NAME_FAMILY_STATUS
# 15              NAME_HOUSING_TYPE
# 16     REGION_POPULATION_RELATIVE
# 17                     DAYS_BIRTH
# 18                  DAYS_EMPLOYED
# 19              DAYS_REGISTRATION
# 20                DAYS_ID_PUBLISH
# 21                    OWN_CAR_AGE
# 22                     FLAG_MOBIL
# 23                 FLAG_EMP_PHONE
# 24                FLAG_WORK_PHONE
# 25               FLAG_CONT_MOBILE
# ...
